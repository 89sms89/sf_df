# %%
import pandas as pd

melb_df = pd.read_csv('data/melb_data_fe.csv')
melb_df.head()
# Out:
#        Suburb  Rooms   Type      Price Method SellerG        Date  Distance  \
# 0  Abbotsford      2  house  1480000.0      S  Biggin  2016-03-12       2.5
# 1  Abbotsford      2  house  1035000.0      S  Biggin  2016-04-02       2.5
# 2  Abbotsford      3  house  1465000.0     SP  Biggin  2017-04-03       2.5
# 3  Abbotsford      3  house   850000.0     PI  Biggin  2017-04-03       2.5
# 4  Abbotsford      4  house  1600000.0     VB  Nelson  2016-04-06       2.5
#
#    Postcode  Bedroom  ...  Longtitude             Regionname  Propertycount  \
# 0      3067        2  ...    144.9984  Northern Metropolitan           4019
# 1      3067        2  ...    144.9934  Northern Metropolitan           4019
# 2      3067        3  ...    144.9944  Northern Metropolitan           4019
# 3      3067        3  ...    144.9969  Northern Metropolitan           4019
# 4      3067        3  ...    144.9941  Northern Metropolitan           4019
#
# ...

# %%
mask1 = melb_df['AreaRatio'] < -0.8
mask2 = melb_df['Type'] == 'townhouse'
mask3 = melb_df['SellerG'] == 'McGrath'
melb_df[mask1 & mask2 & mask3].sort_values(
    by=['Date', 'AreaRatio'],
    ascending=[True, False],
    ignore_index=True
).loc[:, ['Date', 'AreaRatio']]
# Out:
#          Date  AreaRatio
# 0  2016-07-26  -0.974922
# 1  2016-09-24  -0.971831
# 2  2016-11-27  -0.953608
# 3  2016-12-11  -0.945946
# 4  2017-08-04  -0.947368
# 5  2017-08-04  -0.970874

# %%
melb_df.sort_values(by='AreaRatio', ignore_index=True, ascending=False).iloc[1558]
# Out:
# Suburb                       Elsternwick
# Rooms                                  2
# Type                               house
# Price                           716000.0
# Method                                 S
# SellerG                    hockingstuart
# Date                          2017-03-06
# Distance                             7.2
# Postcode                            3185
# Bedroom                                2
# Bathroom                               1
# Car                                    1
# Landsize                             0.0
# BuildingArea                       126.0
# CouncilArea                    Glen Eira
# Lattitude                      -37.89438
# Longtitude                     145.00851
# Regionname         Southern Metropolitan
# Propertycount                       4898
# MeanRoomsSquare                     25.2
# AreaRatio                            1.0
# MonthSale                              3
# AgeBuilding                           47
# ...

# %%
int(melb_df.sort_values(
    by='AreaRatio', 
    ignore_index=True,
    ascending=False
).loc[1558, 'BuildingArea'])
# Out:
# 126

# %%
mask1 = melb_df['Type'] == 'townhouse'
mask2 = melb_df['Rooms'] > 2
int(melb_df[mask1 & mask2].sort_values(
    by=['Rooms', 'MeanRoomsSquare'],
    ascending=[True, False],
    ignore_index=True
    ).loc[18, 'Price'])
# Out:
# 1300000

# %%
melb_df.groupby('Rooms')['Price'].mean()
# Out:
# Rooms
# 1     4.338245e+05
# 2     7.750812e+05
# 3     1.076081e+06
# 4     1.445282e+06
# 5     1.870260e+06
# 6     1.849366e+06
# 7     1.920700e+06
# 8     1.602750e+06
# 10    9.000000e+05
# Name: Price, dtype: float64

# %%
melb_df.groupby('Rooms')['Price'].mean().sort_values(ascending=False)
# Out:
# Rooms
# 7     1.920700e+06
# 5     1.870260e+06
# 6     1.849366e+06
# 8     1.602750e+06
# 4     1.445282e+06
# 3     1.076081e+06
# 10    9.000000e+05
# 2     7.750812e+05
# 1     4.338245e+05
# Name: Price, dtype: float64

# %%
melb_df.groupby('Regionname')['Lattitude'].std().sort_values()
# Out:
# Regionname
# Western Victoria              0.011579
# Southern Metropolitan         0.043080
# Eastern Metropolitan          0.047890
# Northern Metropolitan         0.049639
# Western Metropolitan          0.051251
# South-Eastern Metropolitan    0.073411
# Northern Victoria             0.084455
# Eastern Victoria              0.147067
# Name: Lattitude, dtype: float64

# %%
date1 = pd.to_datetime('2017-05-01')
date2 = pd.to_datetime('2017-09-01')
mask = (date1 <= melb_df['Date']) & (melb_df['Date']<= date2)
melb_df[mask].groupby('SellerG')['Price'].sum().sort_values()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\79265\Documents\IDE_3\sf_df\Skillfactory\PY_12_Advanced_techniques_to_Pandas\Checkpoints.ipynb Ячейка 9 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/79265/Documents/IDE_3/sf_df/Skillfactory/PY_12_Advanced_techniques_to_Pandas/Checkpoints.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> date1 = pd.to_datetime('2017-05-01')
#       <a href='vscode-notebook-cell:/c%3A/Users/79265/Documents/IDE_3/sf_df/Skillfactory/PY_12_Advanced_techniques_to_Pandas/Checkpoints.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> date2 = pd.to_datetime('2017-09-01')
# ----> <a href='vscode-notebook-cell:/c%3A/Users/79265/Documents/IDE_3/sf_df/Skillfactory/PY_12_Advanced_techniques_to_Pandas/Checkpoints.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a> mask = (date1 <= melb_df['Date']) & (melb_df['Date']<= date2)
# ...

# %%
melb_df.pivot_table(
    values='BuildingArea',
    index='Type',
    columns='Rooms',
    aggfunc='median',
    fill_value=0
)
# Out:
# Rooms         1    2    3      4    5    6      7    8    10
# Type
# house      126.0  126  126  141.0  177  126  216.5  126  126
# townhouse   88.0  114  126  159.5  152    0    0.0    0    0
# unit        69.5  110  126  126.0    0  171    0.0  126    0

# %%
melb_df.pivot_table(
    values='BuildingArea',
    index='Rooms',
    columns='Type',
    aggfunc='median',
   fill_value=0 
)
# Out:
# Type   house  townhouse   unit
# Rooms
# 1      126.0       88.0   69.5
# 2      126.0      114.0  110.0
# 3      126.0      126.0  126.0
# 4      141.0      159.5  126.0
# 5      177.0      152.0    0.0
# 6      126.0        0.0  171.0
# 7      216.5        0.0    0.0
# 8      126.0        0.0  126.0
# 10     126.0        0.0    0.0

# %%
a = melb_df.pivot_table(
    values='BuildingArea',
    index='Rooms',
    columns='Type',
    aggfunc='median',
   fill_value=0 
)
print(a.max())
# Out:
# Type
# house        216.5
# townhouse    159.5
# unit         171.0
# dtype: float64

# %%
b = melb_df.pivot_table(
    values='Price',
    index='SellerG',
    columns='Type'
)
display(b)
# Out:
# Type                  house     townhouse           unit
# SellerG
# Alexkarbon     1.103278e+06  9.220000e+05  556172.666667
# Barry          9.331888e+05  7.525791e+05  555870.512821
# Bells          7.262763e+05  4.305000e+05  481250.000000
# Biggin         1.270929e+06  7.210370e+05  568020.833333
# Brad           9.571346e+05  6.978846e+05  480924.657534
# Buckingham     8.480634e+05  9.783333e+05  553000.000000
# Burnham        8.567692e+05           NaN  297730.769231
# Buxton         1.439187e+06  1.138067e+06  664625.954198
# C21            9.693400e+05  7.687500e+05  700700.000000
# Cayzer         1.608258e+06  1.277333e+06  832333.333333
# Chisholm       1.543138e+06  1.056000e+06  658447.651163
# Collins        1.667075e+06  8.750000e+05  571884.615385
# Douglas        6.880360e+05  5.100000e+05  448625.000000
# Eview          8.674119e+05  6.127500e+05  602000.000000
# Fletchers      1.480143e+06  1.248796e+06  691625.000000
# ...

# %%
display(b['unit'].sort_values(ascending=False))
# Out:
# SellerG
# Nick             993642.857143
# Kay              851660.606061
# Cayzer           832333.333333
# Marshall         770044.678261
# Philip           706255.555556
# RT               703509.803922
# C21              700700.000000
# Fletchers        691625.000000
# Williams         685386.486486
# Noel             678085.714286
# Hodges           677227.272727
# Buxton           664625.954198
# Jellis           662828.060897
# Chisholm         658447.651163
# Moonee           649000.000000
# HAR              641000.000000
# Greg             632855.932203
# Woodards         626247.514019
# O'Brien          624000.000000
# Miles            606840.425532
# hockingstuart    604151.664987
# Eview            602000.000000
# RW               598100.000000
# other            586004.938272
# McGrath          579557.692308
# Nelson           574797.970480
# Collins          571884.615385
# Biggin           568020.833333
# Purplebricks     559166.666667
# Alexkarbon       556172.666667
# ...

# %%
max_unit_price = b['unit'].max()
print(b[b['unit'] == max_unit_price].index[0])
# Out:
# Nick

# %%
max_unit_price = b['unit'].max()
print(b[b['unit'] == max_unit_price])
# Out:
# Type           house  townhouse           unit
# SellerG
# Nick     2111984.375   780000.0  993642.857143

# %%
print(b[b['unit'] == max_unit_price].index)
# Out:
# Index(['Nick'], dtype='object', name='SellerG')

# %%
print(b['unit'].max())
# Out:
# 993642.8571428572

# %%
ratings1_df = pd.read_csv('data/ratings1.csv', sep=',')
ratings2_df = pd.read_csv('data/ratings2.csv', sep=',')
dates_df = pd.read_csv('data/dates.csv', sep=',')
movies_df = pd.read_csv('data/movies.csv', sep=',')

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9742 entries, 0 to 9741
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  9742 non-null   int64
#  1   title    9742 non-null   object
#  2   genres   9742 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 228.5+ KB

# %%
movies_df['title'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 9742 entries, 0 to 9741
# Series name: title
# Non-Null Count  Dtype
# --------------  -----
# 9742 non-null   object
# dtypes: object(1)
# memory usage: 76.2+ KB

# %%
movies_df['title'].nunique()
# Out:
# 9737

# %%
ratings1_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40001 entries, 0 to 40000
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   userId   40001 non-null  int64
#  1   movieId  40001 non-null  int64
#  2   rating   40001 non-null  float64
# dtypes: float64(1), int64(2)
# memory usage: 937.6 KB

# %%
ratings1_df['userId'].nunique()
# Out:
# 274

# %%
dates_df['date'] = pd.to_datetime(dates_df['date'], dayfirst=False)
display(dates_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100836 entries, 0 to 100835
# Data columns (total 1 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   date    100836 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 787.9 KB
# None

# %%
dates_df['date'].dt.year.value_counts()
# Out:
# 2000    10061
# 2017     8198
# 2007     7114
# 2016     6703
# 2015     6616
# 2018     6418
# 1996     6040
# 2005     5813
# 2012     4656
# 2008     4351
# 2009     4158
# 2006     4059
# 2003     4014
# 2001     3922
# 2002     3478
# 2004     3279
# 1999     2439
# 2010     2301
# 1997     1916
# 2011     1690
# 2013     1664
# 2014     1439
# 1998      507
# Name: date, dtype: int64

# %%
a = pd.DataFrame({'A': ['a', 'b', 'c'], 'B': [103, 214, 124], 'C': [1, 4, 2]})
b = pd.DataFrame({'V': ['d', 'b', 'c'], 'U': [1393.7, 9382.2, 1904.5], 'C': [1, 3, 2]})

# %%
c = a.merge(b, how='left', on='C')
display(c)
# Out:
#    A    B  C    V       U
# 0  a  103  1    d  1393.7
# 1  b  214  4  NaN     NaN
# 2  c  124  2    c  1904.5

# %%
d = b.join(a.set_index('C'), how='right', on='C')
display(d)
# Out:
#        V       U  C  A    B
# 0.0    d  1393.7  1  a  103
# NaN  NaN     NaN  4  b  214
# 2.0    c  1904.5  2  c  124

# %%
e = a.merge(b, how='right', on='C')
display(e)
# Out:
#      A      B  C  V       U
# 0    a  103.0  1  d  1393.7
# 1  NaN    NaN  3  b  9382.2
# 2    c  124.0  2  c  1904.5

# %%
f = a.merge(b, how='inner', on='C')
display(f)
# Out:
#    A    B  C  V       U
# 0  a  103  1  d  1393.7
# 1  c  124  2  c  1904.5

# %%
items_df = pd.DataFrame({
    'item_id': [417283, 849734, 132223, 573943, 19475, 3294095, 382043, 302948, 100132, 312394], 
    'vendor': ['Samsung', 'LG', 'Apple', 'Apple', 'LG', 'Apple', 'Samsung', 'Samsung', 'LG', 'ZTE'],
    'stock_count': [54, 33, 122, 18, 102, 43, 77, 143, 60, 19]
})

# %%
purchase_df = pd.DataFrame({
    'purchase_id': [101, 101, 101, 112, 121, 145, 145, 145, 145, 221],
    'item_id': [417283, 849734, 132223, 573943, 19475, 3294095, 382043, 302948, 103845, 100132], 
    'price': [13900, 5330, 38200, 49990, 9890, 33000, 67500, 34500, 89900, 11400]
})

# %%
merged = items_df.merge(
    purchase_df,
    on = 'item_id',
    how = 'inner'
)
display(merged)
# Out:
#    item_id   vendor  stock_count  purchase_id  price
# 0   417283  Samsung           54          101  13900
# 1   849734       LG           33          101   5330
# 2   132223    Apple          122          101  38200
# 3   573943    Apple           18          112  49990
# 4    19475       LG          102          121   9890
# 5  3294095    Apple           43          145  33000
# 6   382043  Samsung           77          145  67500
# 7   302948  Samsung          143          145  34500
# 8   100132       LG           60          221  11400

# %%
merged['total'] = merged['stock_count'] * merged['price']
display(merged)
# Out:
#     item_id   vendor  stock_count  purchase_id    price      total
# 0    417283  Samsung         54.0        101.0  13900.0   750600.0
# 1    849734       LG         33.0        101.0   5330.0   175890.0
# 2    132223    Apple        122.0        101.0  38200.0  4660400.0
# 3    573943    Apple         18.0        112.0  49990.0   899820.0
# 4     19475       LG        102.0        121.0   9890.0  1008780.0
# 5   3294095    Apple         43.0        145.0  33000.0  1419000.0
# 6    382043  Samsung         77.0        145.0  67500.0  5197500.0
# 7    302948  Samsung        143.0        145.0  34500.0  4933500.0
# 8    100132       LG         60.0        221.0  11400.0   684000.0
# 9    312394      ZTE         19.0          NaN      NaN        NaN
# 10   103845      NaN          NaN        145.0  89900.0        NaN

# %%
income = merged['total'].sum()
print(income)
# Out:
# 19729490.0

# %%
merged2 = items_df.merge(
    purchase_df,
    on = 'item_id',
    how = 'inner'
)
display(merged2)
# Out:
#    item_id   vendor  stock_count  purchase_id  price
# 0   417283  Samsung           54          101  13900
# 1   849734       LG           33          101   5330
# 2   132223    Apple          122          101  38200
# 3   573943    Apple           18          112  49990
# 4    19475       LG          102          121   9890
# 5  3294095    Apple           43          145  33000
# 6   382043  Samsung           77          145  67500
# 7   302948  Samsung          143          145  34500
# 8   100132       LG           60          221  11400

# %%
ratings_movies = pd.read_csv('data/ratings_movies.csv', sep=',')

# %%
#библиотека для регулярных выражений
import re 
def get_year_release(arg):
    #находим все слова по шаблону "(DDDD)"
    candidates = re.findall(r'\(\d{4}\)', arg) 
    # проверяем число вхождений
    if len(candidates) > 0:
        #если число вхождений больше 0,
	#очищаем строку от знаков "(" и ")"
        year = candidates[0].replace('(', '')
        year = year.replace(')', '')
        return int(year)
    else:
        #если год не указан, возвращаем None
        return None

# %%
ratings_movies['year_release'] = ratings_movies['title'].apply(get_year_release)

# %%
display(ratings_movies.head())
# Out:
#    Unnamed: 0  userId  movieId  rating                 date  \
# 0           0       1        1     4.0  2000-07-30 18:45:03
# 1           1       1        3     4.0  2000-07-30 18:20:47
# 2           2       1        6     4.0  2000-07-30 18:37:04
# 3           3       1       47     5.0  2000-07-30 19:03:35
# 4           4       1       50     5.0  2000-07-30 18:48:51
#
#                          title                                       genres  \
# 0             Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1      Grumpier Old Men (1995)                               Comedy|Romance
# 2                  Heat (1995)                        Action|Crime|Thriller
# 3  Seven (a.k.a. Se7en) (1995)                             Mystery|Thriller
# 4   Usual Suspects, The (1995)                       Crime|Mystery|Thriller
#
#    year_release
# 0        1995.0
# 1        1995.0
# 2        1995.0
# 3        1995.0
# 4        1995.0

# %%
ratings_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100836 entries, 0 to 100835
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    100836 non-null  int64
#  1   userId        100836 non-null  int64
#  2   movieId       100836 non-null  int64
#  3   rating        100836 non-null  float64
#  4   date          100836 non-null  object
#  5   title         100836 non-null  object
#  6   genres        100836 non-null  object
#  7   year_release  100818 non-null  float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 6.2+ MB

# %%
ratings_movies['year_release'].value_counts()
# Out:
# 1995.0    6144
# 1994.0    5296
# 1999.0    4536
# 1996.0    4509
# 2000.0    4268
#           ...
# 1903.0       2
# 1908.0       1
# 1917.0       1
# 1915.0       1
# 1919.0       1
# Name: year_release, Length: 106, dtype: int64

# %%
ratings_movies[ratings_movies['year_release'] == 1999].shape[0]
# Out:
# 4536

# %%
mask = ratings_movies['year_release'] == 1999
ratings_movies[mask].groupby('title')['rating'].mean().sort_values()
# Out:
# title
# Bloodsport: The Dark Kumite (1999)            0.5
# Simon Sez (1999)                              1.0
# Chill Factor (1999)                           1.0
# Source, The (1999)                            1.0
# Trippin' (1999)                               1.0
#                                              ...
# Trailer Park Boys (1999)                      5.0
# Larry David: Curb Your Enthusiasm (1999)      5.0
# Sun Alley (Sonnenallee) (1999)                5.0
# George Carlin: You Are All Diseased (1999)    5.0
# Five Senses, The (1999)                       5.0
# Name: rating, Length: 261, dtype: float64

# %%
mask4 = ratings_movies['year_release'] == 2010
ratings_movies[mask4].groupby('genres')['rating'].mean().sort_values()
# Out:
# genres
# Action|Sci-Fi                        1.000000
# Action|Adventure|Horror              1.500000
# Action|Drama|Fantasy                 1.500000
# Crime|Romance                        1.500000
# Adventure|Comedy|Fantasy             1.833333
#                                        ...
# Crime                                4.750000
# Comedy|Musical                       5.000000
# Animation|Drama|Fantasy|Mystery      5.000000
# Adventure|Children|Comedy|Mystery    5.000000
# Animation|Children|Mystery           5.000000
# Name: rating, Length: 119, dtype: float64

# %%
ratings_movies.groupby('userId')['genres'].nunique().sort_values(ascending=False)
# Out:
# userId
# 599    524
# 414    482
# 448    403
# 380    399
# 474    395
#       ...
# 578     15
# 12      15
# 85      13
# 214     13
# 245     13
# Name: genres, Length: 610, dtype: int64

# %%
ratings_movies.groupby('userId')['rating'].agg(
    ['count', 'mean']
    ).sort_values(by=['count', 'mean'], ascending=[True, False])
# Out:
#         count      mean
# userId
# 53         20  5.000000
# 595        20  4.200000
# 189        20  4.100000
# 569        20  4.000000
# 278        20  3.875000
# ...       ...       ...
# 274      1346  3.235884
# 448      1864  2.847371
# 474      2108  3.398956
# 599      2478  2.642050
# 414      2698  3.391957
#
# [610 rows x 2 columns]

# %%
mask5 = ratings_movies['year_release'] == 2018
grouped = ratings_movies[mask5].groupby('genres')['rating'].agg(['mean', 'count'])

grouped[grouped['count'] > 10].sort_values(
    by='mean',
    ascending=False
)
# Out:
#                              mean  count
# genres
# Action|Adventure|Sci-Fi  3.928571     14
# Action|Comedy|Sci-Fi     3.875000     12

# %%
ratings_movies['date'] = pd.to_datetime(ratings_movies['date'], dayfirst=False)
ratings_movies['year_rating'] = ratings_movies['date'].dt.year

# %%
pivot = ratings_movies.pivot_table(
    values='rating',
    index='year_rating',
    columns='genres',
    aggfunc='mean'
)
display(pivot)
# Out:
# genres       (no genres listed)    Action  Action|Adventure  \
# year_rating
# 1996                        NaN  2.730769          3.454545
# 1997                        NaN  3.538462          4.150000
# 1998                        NaN       NaN          4.200000
# 1999                        NaN       NaN          4.000000
# 2000                        NaN  2.588235          3.738462
# 2001                        NaN  3.000000          3.500000
# 2002                        NaN  2.750000          4.304348
# 2003                        NaN  3.833333          3.277778
# 2004                        NaN  2.700000          4.136364
# 2005                        NaN  3.357143          3.413043
# 2006                        NaN  2.166667          4.090909
# 2007                        NaN  2.583333          3.666667
# 2008                        NaN  3.000000          3.656250
# 2009                        NaN       NaN          3.714286
# ...

# %%
pivot['Action|Adventure'].min()
# Out:
# 3.2777777777777777

# %%
rat2010 = pivot['Action|Adventure|Animation|Children|Comedy|IMAX'].loc[2010]
max_rat = pivot['Action|Adventure|Animation|Children|Comedy|IMAX'].max()
print(rat2010 == max_rat)
# Out:
# False

# %%
pivot.loc[2018, 'Animation|Children|Mystery']
# Out:
# 5.0

# %%
pivot.loc[2018].sort_values(ascending=False).head(30)
# Out:
# genres
# Animation|Comedy|Drama                            5.00
# Crime|Mystery                                     5.00
# Comedy|Crime|Fantasy                              5.00
# Crime|Fantasy|Horror                              5.00
# Comedy|Crime|Horror|Thriller                      5.00
# Animation|Crime|Drama                             5.00
# Drama|Romance|War                                 5.00
# Action|Comedy|Documentary                         5.00
# Animation|Comedy|Fantasy|Musical                  5.00
# Animation|Comedy|Drama|Fantasy|Sci-Fi             5.00
# Comedy|Drama|Fantasy|Mystery|Romance              5.00
# Animation|Children|Mystery                        5.00
# Drama|Horror|Mystery|Sci-Fi|Thriller              5.00
# Adventure|Children|Comedy|Fantasy|Mystery         5.00
# Comedy|Fantasy|Horror|Musical|Thriller            5.00
# Romance|Sci-Fi                                    5.00
# Mystery|Romance|Sci-Fi|Thriller                   5.00
# ...

# %%
pivot['Comedy']
# Out:
# year_rating
# 1996    3.228571
# 1997    3.409091
# 1998    3.000000
# 1999    3.606061
# 2000    3.141291
# 2001    3.318408
# 2002    3.198556
# 2003    3.120066
# 2004    3.356877
# 2005    2.963325
# 2006    3.347534
# 2007    2.928187
# 2008    3.426667
# 2009    3.273292
# 2010    3.179825
# 2011    3.232877
# 2012    3.478477
# 2013    3.489474
# 2014    3.271429
# 2015    3.106183
# 2016    3.373431
# 2017    2.852668
# 2018    3.121296
# Name: Comedy, dtype: float64

# %%
orders_df = pd.read_csv('data/orders.csv', sep=';')
products_df = pd.read_csv('data/products.csv', sep=';')

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Дата создания  18 non-null     object
#  1   Order ID       18 non-null     int64
#  2   ID Покупателя  18 non-null     int64
#  3   Статус         18 non-null     object
#  4   Оплачен        18 non-null     object
#  5   Отменен        18 non-null     object
#  6   Отгружен       18 non-null     object
#  7   ID товара      18 non-null     int64
#  8   Количество     18 non-null     int64
# dtypes: int64(4), object(5)
# memory usage: 1.4+ KB

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Product_ID  14 non-null     int64
#  1   Name        14 non-null     object
#  2   Price       14 non-null     int64
#  3   CURRENCY    14 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 576.0+ bytes

# %%
display(orders_df)
# Out:
#           Дата создания  Order ID  ID Покупателя  \
# 0   09.11.2019 21:55:51         9             10
# 1   09.11.2019 15:05:57         8              9
# 2   09.11.2019 15:05:57         8              9
# 3   09.11.2019 12:50:07         7              8
# 4   09.11.2019 12:00:00         6              1
# 5   09.11.2019 12:00:00         6              1
# 6   08.11.2019 08:36:22         5              5
# 7   08.11.2019 08:36:22         4              9
# 8   08.11.2019 08:36:22         3              8
# 9   08.11.2019 08:36:22         3              8
# 10  08.11.2019 08:36:21         2              7
# 11  08.11.2019 08:36:21         2              7
# 12  08.11.2019 08:36:21         2              7
# 13  08.11.2019 08:36:21         2              7
# 14  08.11.2019 08:36:20         1              5
# 15  08.11.2019 08:36:20         1              5
# 16  08.11.2019 08:36:20         1              5
# 17  01.01.2001 00:00:00         0              1
#
# ...

# %%
display(products_df)
# Out:
#     Product_ID                                   Name  Price CURRENCY
# 0           47                   Шатны Полосатый рейс   2999      RUR
# 1           51               Платье Аленький цветочек   4999      RUR
# 2           53                 Штаны Цветочная Поляна   4999      RUR
# 3           71                    Платье Ночная Жизнь   7999      RUR
# 4           74               Платье Ночная Жизнь XXXL   8999      RUR
# 5           86                     Носки Простые, муж     45      RUR
# 6           91                     Носки Честные, муж     50      RUR
# 7          103                  Носки Подарочные, муж    199      RUR
# 8          104                  Носки Подарочные, жен    249      RUR
# 9          124                   Носки беговые Camino    999      RUR
# 10         137              Гольфы детские Снегурочка     99      RUR
# 11         138               Гольфы детские Питер Пен     99      RUR
# ...

# %%
orders_products = orders_df.merge(
    products_df,
    left_on='ID товара',
    right_on='Product_ID',
    how='left'
)
display(orders_products)
# Out:
#           Дата создания  Order ID  ID Покупателя  \
# 0   09.11.2019 21:55:51         9             10
# 1   09.11.2019 15:05:57         8              9
# 2   09.11.2019 15:05:57         8              9
# 3   09.11.2019 12:50:07         7              8
# 4   09.11.2019 12:00:00         6              1
# 5   09.11.2019 12:00:00         6              1
# 6   08.11.2019 08:36:22         5              5
# 7   08.11.2019 08:36:22         4              9
# 8   08.11.2019 08:36:22         3              8
# 9   08.11.2019 08:36:22         3              8
# 10  08.11.2019 08:36:21         2              7
# 11  08.11.2019 08:36:21         2              7
# 12  08.11.2019 08:36:21         2              7
# 13  08.11.2019 08:36:21         2              7
# 14  08.11.2019 08:36:20         1              5
# 15  08.11.2019 08:36:20         1              5
# 16  08.11.2019 08:36:20         1              5
# 17  01.01.2001 00:00:00         0              1
#
# ...

# %%
orders_products.tail(1)
# Out:
#           Дата создания  Order ID  ID Покупателя  \
# 17  01.01.2001 00:00:00         0              1
#
#                              Статус Оплачен Отменен Отгружен  ID товара  \
# 17  Оплачен, формируется к отправке      Да     Нет      Нет        666
#
#     Количество  Product_ID Name  Price CURRENCY
# 17           1         NaN  NaN    NaN      NaN

# %%
orders_products.tail(1)['Order ID']
# Out:
# 17    0
# Name: Order ID, dtype: int64

# %%
orders_products[orders_products['Отменен'] == 'Да']['Name']
# Out:
# 6    Носки беговые Camino
# Name: Name, dtype: object

# %%
orders_products['Profit'] = orders_products['Price'] * orders_products['Количество'] 
orders_products[orders_products['Оплачен'] == 'Да'].groupby('ID Покупателя')['Profit'].sum().sort_values(ascending=False)
# Out:
# ID Покупателя
# 7    17096.0
# 5    13043.0
# 8     1344.0
# 1        0.0
# Name: Profit, dtype: float64

# %%
orders_df.head()
# Out:
#          Дата создания  Order ID  ID Покупателя                    Статус  \
# 0  09.11.2019 21:55:51         9             10  Принят, ожидается оплата
# 1  09.11.2019 15:05:57         8              9  Принят, ожидается оплата
# 2  09.11.2019 15:05:57         8              9  Принят, ожидается оплата
# 3  09.11.2019 12:50:07         7              8  Принят, ожидается оплата
# 4  09.11.2019 12:00:00         6              1  Принят, ожидается оплата
#
#   Оплачен Отменен Отгружен  ID товара  Количество
# 0     Нет     Нет      Нет        103           5
# 1     Нет     Нет      Нет         86         100
# 2     Нет     Нет      Нет        104          10
# 3     Нет     Нет      Нет        104           7
# 4     Нет     Нет      Нет        104           5

# %%
products_df.head()
# Out:
#    Product_ID                      Name  Price CURRENCY
# 0          47      Шатны Полосатый рейс   2999      RUR
# 1          51  Платье Аленький цветочек   4999      RUR
# 2          53    Штаны Цветочная Поляна   4999      RUR
# 3          71       Платье Ночная Жизнь   7999      RUR
# 4          74  Платье Ночная Жизнь XXXL   8999      RUR

# %%
merged = orders_df.merge(
    products_df,
    left_on='ID товара',
    right_on='Product_ID',
    how='left'
)
merged
# Out:
#           Дата создания  Order ID  ID Покупателя  \
# 0   09.11.2019 21:55:51         9             10
# 1   09.11.2019 15:05:57         8              9
# 2   09.11.2019 15:05:57         8              9
# 3   09.11.2019 12:50:07         7              8
# 4   09.11.2019 12:00:00         6              1
# 5   09.11.2019 12:00:00         6              1
# 6   08.11.2019 08:36:22         5              5
# 7   08.11.2019 08:36:22         4              9
# 8   08.11.2019 08:36:22         3              8
# 9   08.11.2019 08:36:22         3              8
# 10  08.11.2019 08:36:21         2              7
# 11  08.11.2019 08:36:21         2              7
# 12  08.11.2019 08:36:21         2              7
# 13  08.11.2019 08:36:21         2              7
# 14  08.11.2019 08:36:20         1              5
# 15  08.11.2019 08:36:20         1              5
# 16  08.11.2019 08:36:20         1              5
# 17  01.01.2001 00:00:00         0              1
#
# ...

# %%
merged[merged['Product_ID'].isnull()]['Order ID']
# Out:
# 17    0
# Name: Order ID, dtype: int64

# %%
merged[merged['Отменен'] == 'Да']['Name']
# Out:
# 6    Носки беговые Camino
# Name: Name, dtype: object

# %%
merged['Profit'] = merged['Количество'] * merged['Price']

merged[merged['Оплачен'] == 'Да'].groupby('ID Покупателя')['Profit'].sum().sort_values(ascending=False).head(1).index[0]
# Out:
# 7
